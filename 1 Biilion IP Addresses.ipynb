# %% [markdown]
# <b>FIND AVAILABLE IP ADDRESSES THAT ARE NOT IN A GIVEN LIST:</b>

# %% [markdown]
# <b>Make a list of random ips:</b>

# %%
import random as r
possibles = 256
rang = 100000
ips = {(r.randrange(possibles), r.randrange(possibles), r.randrange(possibles), r.randrange(possibles)) for i in range(rang)}

# %%
print(ips)
# Out:
# {(203, 15, 58, 45), (152, 68, 228, 134), (253, 222, 11, 191), (158, 108, 58, 175), (154, 4, 215, 67), (0, 38, 113, 138), (252, 245, 9, 160), (141, 223, 248, 40), (226, 81, 194, 198), (148, 47, 112, 139), (158, 32, 53, 143), (219, 39, 96, 50), (130, 2, 60, 233), (116, 137, 85, 65), (97, 153, 41, 200), (230, 165, 11, 181), (32, 82, 41, 152), (30, 88, 47, 23), (156, 44, 77, 127), (76, 76, 36, 144), (80, 136, 52, 54), (244, 202, 15, 116), (255, 158, 238, 97), (28, 13, 162, 82), (139, 115, 98, 196), (178, 109, 108, 80), (109, 116, 89, 87), (40, 212, 96, 144), (80, 220, 35, 96), (234, 155, 150, 100), (2, 194, 149, 149), (211, 244, 114, 126), (61, 221, 194, 1), (215, 91, 4, 85), (29, 81, 34, 92), (162, 16, 59, 97), (135, 234, 228, 111), (223, 119, 6, 159), (160, 69, 247, 18), (178, 254, 155, 161), (154, 58, 206, 169), (210, 33, 61, 69), (155, 172, 154, 188), (15, 37, 33, 216), (72, 165, 151, 91), (1, 12, 244, 49), (43, 124, 156, 196), (152, 74, 239, 9), (205, 56, 235, 99), (51, 40, 226, 39), (227, 89, 211, 251), (109, 47, 105, 1), (44, 72, 236, 44), (215, 27, 104, 246), (254, 62, 221, 250), (83, 104, 229, 194), (27, 27, 222, 204), (211, 170, 136, 234), (61, 48, 88, 111), (52, 3, 0, 210), (22, 96, 227, 203), (39, 121, 192, 193), (203, 176, 9, 149), (131, 159, 135, 244), (62, 143, 104, 67), (243, 23, 65, 247), (206, 73, 223, 23), (10, 127, 116, 154), (185, 173, 21, 174), (108, 83, 152, 243), (224, 228, 124, 255), (179, 121, 135, 89), (252, 196, 118, 123), (251, 181, 90, 225), (177, 88, 144, 33), (48, 200, 243, 231), (98, 191, 224, 200), (129, 118, 184, 171), (198, 222, 28, 87), (117, 101, 112, 238), (232, 138, 26, 100), (75, 75, 163, 148), (239, 254, 84, 111), (217, 48, 190, 58), (100, 122, 154, 135), (195, 81, 214, 33), (174, 252, 207, 246), (106, 209, 187, 78), (160, 153, 146, 82), (56, 216, 218, 114), (149, 54, 223, 64), (115, 116, 22, 115), (131, 173, 201, 202), (149, 61, 1, 22), (162, 235, 214, 30), (187, 18, 65, 181), (151, 222, 124, 116), (25, 81, 82, 149), (175, 252, 15, 253), (199, 127, 102, 197), (216, 153, 220, 137), (38, 33, 39, 29), (42, 99, 78, 177), (72, 20, 79, 186), (161, 149, 238, 234), (19, 244, 210, 164), (152, 58, 117, 133), (237, 34, 16, 54), (0, 28, 80, 80), (212, 195, 252, 25), (44, 229, 98, 125), (15, 4, 3, 195), (205, 37, 184, 239), (174, 5, 50, 20), (234, 37, 247, 136), (170, 48, 220, 17), (26, 202, 47, 175), (51, 185, 243, 39), (90, 207, 231, 144), (238, 252, 131, 17), (36, 179, 128, 233), (196, 62, 37, 90), (185, 163, 185, 101), (168, 42, 220, 153), (194, 34, 54, 1), (45, 221, 201, 183), (201, 103, 68, 102), (162, 188, 230, 121), (134, 39, 130, 39), (144, 172, 2, 176), (222, 173, 67, 208), (63, 17, 116, 236), (122, 50, 157, 253), (105, 159, 196, 156), (138, 93, 95, 31), (172, 187, 206, 210), (126, 149, 112, 222), (110, 150, 125, 54), (241, 238, 18, 23), (154, 127, 166, 146), (16, 107, 99, 47), (29, 74, 28, 83), (24, 159, 50, 116), (80, 16, 198, 201), (253, 123, 137, 190), (174, 86, 182, 117), (19, 42, 88, 122), (250, 169, 112, 100), (176, 143, 52, 235), (115, 128, 234, 35), (224, 78, 159, 159), (242, 174, 0, 239), (60, 221, 2, 97), (75, 30, 114, 108), (209, 121, 108, 98), (125, 242, 253, 30), (98, 40, 148, 153), (253, 125, 128, 92), (223, 113, 39, 249), (247, 212, 242, 106), (39, 213, 111, 168), (178, 179, 164, 230), (224, 177, 111, 175), (114, 197, 109, 1), (59, 140, 218, 206), (137, 212, 163, 185), (137, 114, 73, 179), (60, 145, 37, 99), (60, 105, 135, 161), (24, 216, 63, 199), (12, 43, 113, 221), (203, 94, 167, 125), (230, 214, 142, 222), (201, 231, 189, 23), (170, 178, 152, 153), (34, 102, 106, 166), (103, 146, 125, 9), (149, 209, 18, 168), (16, 230, 118, 11), (192, 71, 110, 101), (59, 197, 149, 182), (212, 246, 186, 46), (100, 245, 237, 81), (210, 87, 25, 17), (1, 218, 33, 63), (226, 226, 54, 4), (63, 171, 52, 27), (163, 218, 43, 249), (151, 82, 74, 29), (54, 155, 85, 151), (64, 16, 31, 250), (151, 12, 100, 105), (85, 127, 229, 86), (165, 51, 16, 83), (128, 41, 17, 238), (235, 89, 28, 45), (245, 211, 2 ...

# %%
def isPossible(a,b,c,d, list):
    if (a,b,c,d) not in list:
        return True

# %% [markdown]
# <b>The long, terrible method I came up with, only gives 1 IP address:</b>

# %%
def another_method(list, possibles):
        
    # Create 4 dicts that store all number from 0 to 255 and their counts in list.
    dict1, dict2, dict3, dict4 = ({k:0 for k in range(possibles)} for i in range(4))
    for (a,b,c,d) in list:
            dict1[a] = dict1.get(a, 0) + 1
            dict2[b] = dict2.get(b, 0) + 1
            dict3[c] = dict3.get(c, 0) + 1
            dict4[d] = dict4.get(d, 0) + 1
            
    # Get 4 number with the smallest counts (Hence more likely to be usable)       
    a = min(dict1, key=dict1.get)
    b = min(dict2, key=dict2.get)
    c = min(dict3, key=dict3.get)
    d = min(dict4, key=dict4.get)
    
    # Go thourgh 4 dicts...
    for dic in (dict1, dict2, dict3, dict4):    
        num_with_lowest_count = min(dic, key=dic.get)
        if dic[num_with_lowest_count] == 0:  # find that 1 number that has not been used
            x = num_with_lowest_count
            print("available ip is %d:%d:%d:%d!!" % (x,x,x,x))
            break
    else:
        for n in range(256):
            if isPossible(n, b,c,d, list):
                print("(%d, %d, %d, %d)" % (a,n,c,d))
                break
            if isPossible(a, n,c,d, list):
                print("(%d, %d, %d, %d)" % (a,n,c,d))
                break
            if isPossible(a, b,n,d, list):
                print("(%d, %d, %d, %d)" % (a,b,n,d))
                break
            if isPossible(a, b,c,n, list):
                print("(%d, %d, %d, %d)" % (a,b,c,n))
                break

# %% [markdown]
# <b>Recursion method: Generate random IP from list:</b>

# %%
def recursion_method(list, possibles):
    def generate_random():
        return (r.randrange(possibles), r.randrange(possibles), r.randrange(possibles), r.randrange(possibles))

    def find_available(list):
        ip = generate_random()
        if ip not in list:
            return ip
        else:
            find_available(list)
    
    return find_available(list)

# %%
recursion_method(ips, possibles)
# Out:
# (20, 234, 128, 129)

# %%
another_method(ips, possibles)
# Out:
# (166, 0, 71, 40)
